# %%
import cv2

# %%
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
print("Camera opened: ",cap.isOpened())
# Out:
# Camera opened:  False

# %%
import cv2
#Open default camera(0 = laptop webcam)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read() #read frame from camera

    if not ret:
        print("Failed to grab frame")
        break

    cv2.imshow("laptop camera",frame) # show the frame

    #press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# Failed to grab frame
# [ WARN:0@232.342] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@232.343] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range

# %%
import cv2

cap = cv2.VideoCapture("sample_video.mp4")

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    cv2.imshow("Video",frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Display Video Properties

import cv2

cap = cv2.VideoCapture("sample_video.mp4")

total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

print("Total frames:",total_frames)
print("fps:",fps)
print("width",width)
print("height:",height)

cap.release()
# Out:
# Total frames: 0
# fps: 0.0
# width 0.0
# height: 0.0

# %%
import cv2

cap = cv2.VideoCapture("sample_video.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Grayscale video:",gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture("sample_video.mp4")

while True:
    ret, frame = cap.read()
    if ret:
        break

    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    print(gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_55/1939451987.py in <cell line: 0>()
#       8         break
#       9
# ---> 10     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#      11     print(gray)
#      12
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.rectangle(frame, (100,100),(300,300),(0,255,0),3)
    cv2.circle(frame,(200,200),50,(255,0,0),3)

    cv2.putText(frame,"OpenCV practice",(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)

    cv2.imshow("Shapes",frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@303.453] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@303.453] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    edges = cv2.Canny(frame,100,200)

    cv2.imshow("Edges",edges)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@319.020] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@319.020] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
